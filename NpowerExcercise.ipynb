# %% [markdown]
# <a href="https://colab.research.google.com/github/Amanuel2537/0x01.c/blob/master/NpowerExcercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
handle=open("Text.txt","r")
print(handle.read())
# Out:
# Line 1
#
# Line 2
#
# Line 3
#
# finished

# %%
handle.close()

# %%
with open("Text.txt","r") as handle:
  print(handle.read())
# Out:
# Line 1
#
# Line 2
#
# Line 3
#
# finished

# %%
handle.name
# Out:
# 'Text.txt'

# %%
handle.mode
# Out:
# 'r'

# %%
handle=open("Text.txt","r")
print(handle.read(6))
# Out:
# Line 1

# %%
print(handle.read(2))
handle.close()

# %%
handle=open("Text.txt","r")
for x in handle:
  print(x)
# Out:
# Line 1
#
#
#
# Line 2
#
#
#
# Line 3
#
#
#
# finished

# %%
handle1=open("Text.txt","r")

# %% [markdown]
# Read The content of the Entire File

# %%
f=open("Textwritemode.txt","w")
f.write("This is my file")
f.close()

# %%
f=open("Textwritemode.txt","a")
f.write("This is my file Don't touch it")
f.close()

# %%
my=open("Textwritemode.txt","r")
print(my.read())
# Out:
# This is my fileThis is my file Don't touch itThis is my file Don't touch itThis is my file Don't touch it

# %%
import pandas as pd
matches_def1=pd.read_csv("matches.csv")
matches_def1
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
import pandas as pd
matches_def1=pd.read_csv("matches.csv",index_col="season")
matches_def1
# Out:
#            id           city        date                        team1  \
# season
# 2017        1      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2017        2           Pune  2017-04-06               Mumbai Indians
# 2017        3         Rajkot  2017-04-07                Gujarat Lions
# 2017        4         Indore  2017-04-08       Rising Pune Supergiant
# 2017        5      Bangalore  2017-04-08  Royal Challengers Bangalore
# ...       ...            ...         ...                          ...
# 2019    11347         Mumbai    05/05/19        Kolkata Knight Riders
# 2019    11412        Chennai    07/05/19          Chennai Super Kings
# 2019    11413  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 2019    11414  Visakhapatnam    10/05/19               Delhi Capitals
# 2019    11415      Hyderabad    12/05/19               Mumbai Indians
#
#                               team2                  toss_winner  \
# season
# ...

# %%
.0matches
