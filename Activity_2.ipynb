# %% [markdown]
# <a href="https://colab.research.google.com/github/Amanuel2537/0x01.c/blob/master/Activity_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1,Download cities.csv in C7W1 Activity folder
# 2) Import the CSV in a dataframe
# 3) Add a column to the dataframe
# 4) Perform describe and info on dataframe
# 5) Export and save this data as cities1.csv
# 1) Download CarSalesByModelStart.xlsx in C7W1 Activity folder
# 2) Import xlsx in a dataframe
# 3) Add a column to the dataframe
# 4) Perform describe and info on dataframe
# 5) Export and save this data as CarSalesByModelStart1.xlsx
# 1) Download Jay.json in C7W1 Activity folder
# 2) Import the Json in dataframe
# 3) Add a column to the dataframe
# 4) Perform describe and info on dataframe
# 5) Export and save this data as Jay1.jso

# %%
import pandas as pd
df=pd.read_csv("/content/cities.csv")
df.head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State"
# 0        "Youngstown"       OH
# 1           "Yankton"       SD
# 2            "Yakima"       WA
# 3         "Worcester"       MA
# 4   "Wisconsin Dells"       WI

# %%
df["newColumn"]=None
df.head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State" newColumn
# 0        "Youngstown"       OH      None
# 1           "Yankton"       SD      None
# 2            "Yakima"       WA      None
# 3         "Worcester"       MA      None
# 4   "Wisconsin Dells"       WI      None

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LatD       128 non-null    int64
#  1    "LatM"    128 non-null    int64
#  2    "LatS"    128 non-null    int64
#  3    "NS"      128 non-null    object
#  4    "LonD"    128 non-null    int64
#  5    "LonM"    128 non-null    int64
#  6    "LonS"    128 non-null    int64
#  7    "EW"      128 non-null    object
#  8    "City"    128 non-null    object
#  9    "State"   128 non-null    object
#  10  newColumn  0 non-null      object
# dtypes: int64(6), object(5)
# memory usage: 11.1+ KB

# %%
df.to_csv("/content/cities1.csv")

# %%
import pandas as pd
df1=pd.read_excel("/content/CarSalesByModelStart.xlsx")
df.head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State" newColumn
# 0        "Youngstown"       OH      None
# 1           "Yankton"       SD      None
# 2            "Yakima"       WA      None
# 3         "Worcester"       MA      None
# 4   "Wisconsin Dells"       WI      None

# %%
df1["New Column"]=None
df.head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State" newColumn
# 0        "Youngstown"       OH      None
# 1           "Yankton"       SD      None
# 2            "Yakima"       WA      None
# 3         "Worcester"       MA      None
# 4   "Wisconsin Dells"       WI      None

# %%
df1.describe()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           1200 non-null   int64
#  1   Month          1200 non-null   object
#  2   Date           1200 non-null   datetime64[ns]
#  3   Model          1200 non-null   object
#  4   Dealer ID      1200 non-null   int64
#  5   Quantity Sold  1200 non-null   int64
#  6   Profit         1200 non-null   float64
#  7   New Column     0 non-null      object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 75.1+ KB

# %%
df1.to_excel("/content/CarSalesByModelStart1.xlsx")

# %%
df2=pd.read_json("/content/Jay (1).json")
df.head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State" newColumn
# 0        "Youngstown"       OH      None
# 1           "Yankton"       SD      None
# 2            "Yakima"       WA      None
# 3         "Worcester"       MA      None
# 4   "Wisconsin Dells"       WI      None

# %%
df2["NewColumn"]=None
df2.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories NewColumn
# 0        60    110       130     409.1      None
# 1        60    117       145     479.0      None
# 2        60    103       135     340.0      None
# 3        45    109       175     282.4      None
# 4        45    117       148     406.0      None

# %%
df2.describe()
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Duration   169 non-null    int64
#  1   Pulse      169 non-null    int64
#  2   Maxpulse   169 non-null    int64
#  3   Calories   164 non-null    float64
#  4   NewColumn  0 non-null      object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 12.0+ KB
#    Duration  Pulse  Maxpulse  Calories NewColumn
# 0        60    110       130     409.1      None
# 1        60    117       145     479.0      None
# 2        60    103       135     340.0      None
# 3        45    109       175     282.4      None
# 4        45    117       148     406.0      None

# %%
df2.to_json("/content/Jay1 (1).json")
df.head()
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State" newColumn
# 0        "Youngstown"       OH      None
# 1           "Yankton"       SD      None
# 2            "Yakima"       WA      None
# 3         "Worcester"       MA      None
# 4   "Wisconsin Dells"       WI      None
