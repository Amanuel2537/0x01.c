# %% [markdown]
# <a href="https://colab.research.google.com/github/Amanuel2537/0x01.c/blob/master/ACTIVITY_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d={'Mouse':[150,200,300,400],
   'Keyboard':[180,200,190,300],
   'Scanner':[200,280,330,450]}
df=pd.DataFrame(d,index=['Ja','Fe','Marc','Apri'])

# %%
# Write code to access data of Mouse and Scanner columns
df[["Mouse","Scanner"]]
# Out:
#       Mouse  Scanner
# Ja      150      200
# Fe      200      280
# Marc    300      330
# Apri    400      450

# %%
# Write code to access data of the Keyboard column using dot notation and column name
df.Keyboard
# Out:
# Ja      180
# Fe      200
# Marc    190
# Apri    300
# Name: Keyboard, dtype: int64

# %%
# Write code to access data of scanners using loc[]
df.loc[:,"Scanner"]
# Out:
# Ja      200
# Fe      280
# Marc    330
# Apri    450
# Name: Scanner, dtype: int64

# %%
# Write code to access data of all columns where mouse data is more than 200.
df[df['Mouse']>200]
# Out:
#       Mouse  Keyboard  Scanner
# Marc    300       190      330
# Apri    400       300      450

# %%
#Write code to access columns using 0 and 2
df.iloc[:,[0,2]]
# Out:
#       Mouse  Scanner
# Ja      150      200
# Fe      200      280
# Marc    300      330
# Apri    400      450

# %%
#Write code to access data of rows of jan and march for scanner and keyboard
df.loc[['Ja','Marc'],["Scanner","Keyboard"]]
# Out:
#       Scanner  Keyboard
# Ja        200       180
# Marc      330       190
